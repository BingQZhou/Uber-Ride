# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import methods as mt
import datetime
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Load Datasets

# %%
barts_to_all = pd.read_csv("data/barts_to_all.csv")
barts_hotspots = pd.read_csv("data/barts_hotspots.csv")
hotspots_to_all = pd.read_csv("data/hotspots_to_all.csv")
hours_q1 = pd.read_csv("data/hours_q1.csv")
hours_q2 = pd.read_csv("data/hours_q2.csv")

# %%
barts_to_all
# Out:
#        Origin Movement ID                                Origin Display Name  \
# 0                    3603                     Embarcadero, San Francisco, CA
# 1                    3603                     Embarcadero, San Francisco, CA
# 2                    3603                     Embarcadero, San Francisco, CA
# 3                    3603                     Embarcadero, San Francisco, CA
# 4                    3603                     Embarcadero, San Francisco, CA
# ...                   ...                                                ...
# 10868                3760  Powell BART Station, Market St and Powell St, ...
# 10869                3760  Powell BART Station, Market St and Powell St, ...
# 10870                3760  Powell BART Station, Market St and Powell St, ...
# 10871                3760  Powell BART Station, Market St and Powell St, ...
# 10872                3760  Powell BART Station, Market St and Powell St, ...
#
# ...

# %%
#can self define times
barts_hotspots #travel between specific barts and hotspots (3-3)
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 1     04/28/2019                3603
# 2     05/18/2019                3603
# 3     04/18/2019                3792
# 4     04/08/2019                3792
# ...          ...                 ...
# 3253  01/06/2019                3396
# 3254  01/24/2019                3396
# 3255  01/09/2019                3760
# 3256  02/04/2019                3760
# 3257  03/04/2019                3760
#
#                                     Origin Display Name  \
# 0     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 1                        Embarcadero, San Francisco, CA
# 2                        Embarcadero, San Francisco, CA
# 3     Oracle Park, 24 Willie Mays Plaza, San Francis...
# 4     Oracle Park, 24 Willie Mays Plaza, San Francis...
# ...                                                 ...
# 3253  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3254  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# ...

# %%
hotspots_to_all
# Out:
#       Origin Movement ID                                Origin Display Name  \
# 0                   3394               Fisherman's Wharf, San Francisco, CA
# 1                   3394               Fisherman's Wharf, San Francisco, CA
# 2                   3394               Fisherman's Wharf, San Francisco, CA
# 3                   3394               Fisherman's Wharf, San Francisco, CA
# 4                   3394               Fisherman's Wharf, San Francisco, CA
# ...                  ...                                                ...
# 7816                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7817                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7818                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7819                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7820                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
# ...

# %%
hours_q1
# Out:
#         sourceid  dstid  hod  mean_travel_time  \
# 0           3768   3700    3            161.58
# 1           3772   3660    3            373.98
# 2           3751   3708    6           1197.27
# 3           3761   3608    6            588.32
# 4           3767   3724   17            438.98
# ...          ...    ...  ...               ...
# 633167      3393   3390   23            592.03
# 633168      3395   3399   20           1113.72
# 633169      3399   3398    9           1145.57
# 633170      3391   3398    4             97.24
# 633171      3390   3393   21            664.02
#
#         standard_deviation_travel_time  geometric_mean_travel_time  \
# 0                                87.83                      147.02
# 1                               217.24                      328.16
# 2                               259.18                     1171.36
# 3                               223.30                      557.92
# ...

# %%
hours_q2
# Out:
#         sourceid  dstid  hod  mean_travel_time  \
# 0           3709   3671   13            875.06
# 1           3708   3681   13            850.12
# 2           3632   3715    8           1017.34
# 3           3642   3615    8             94.17
# 4           3643   3605    8            171.74
# ...          ...    ...  ...               ...
# 635560      3395   3391   16            454.32
# 635561      3394   3393   17           2666.26
# 635562      3393   3395   18            311.48
# 635563      3398   3391   15            153.51
# 635564      3390   3393    8            756.88
#
#         standard_deviation_travel_time  geometric_mean_travel_time  \
# 0                               232.37                      850.74
# 1                               224.94                      826.64
# 2                               298.82                      973.40
# 3                                75.18                       71.61
# ...

# %% [markdown]
# ## Split the barts_spots dataset to two datasets with bart_origins and hotspot_origins

# %%
#Figure out the ids and the names of barts and hotspots
ids = barts_hotspots["Origin Movement ID"].unique()
names = barts_hotspots["Origin Display Name"].unique()
id_name_dict = dict(zip(ids, names))
id_name_dict
# Out:
# {3396: 'The Palace Of Fine Arts, 3601 Lyon St, San Francisco, CA',
#  3603: 'Embarcadero, San Francisco, CA',
#  3792: 'Oracle Park, 24 Willie Mays Plaza, San Francisco, CA',
#  3394: "Fisherman's Wharf, San Francisco, CA",
#  3692: '2nd Street and Stevenson Street (Montgomery BART, San Francisco, CA',
#  3760: 'Powell BART Station, Market St and Powell St, San Francisco, CA'}

# %%
bart_ids = [3603, 3692, 3760]
hotspot_ids = [3396, 3792, 3394]

# %%
#Split the table
boo_ls = barts_hotspots["Origin Movement ID"].isin(bart_ids)
bart_origins = barts_hotspots.loc[boo_ls]
bart_origins.head()
# Out:
#          Date  Origin Movement ID             Origin Display Name  \
# 1  04/28/2019                3603  Embarcadero, San Francisco, CA
# 2  05/18/2019                3603  Embarcadero, San Francisco, CA
# 6  04/23/2019                3603  Embarcadero, San Francisco, CA
# 7  05/13/2019                3603  Embarcadero, San Francisco, CA
# 9  04/14/2019                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 6                     3394               Fisherman's Wharf, San Francisco, CA
# 7                     3394               Fisherman's Wharf, San Francisco, CA
# 9                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 1                             639.0
# ...

# %% [markdown]
# ## Convert date to day of week

# %%
#convert date to datetime
conversion = lambda x: pd.to_datetime(x)
bart_origins['Date'] = bart_origins['Date'].apply(conversion)
bart_origins
# Out:
# C:\Users\QYK\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#            Date  Origin Movement ID  \
# 1    2019-04-28                3603
# 2    2019-05-18                3603
# 6    2019-04-23                3603
# 7    2019-05-13                3603
# 9    2019-04-14                3603
# ...         ...                 ...
# 3247 2019-02-13                3760
# 3250 2019-03-18                3760
# 3255 2019-01-09                3760
# 3256 2019-02-04                3760
# 3257 2019-03-04                3760
#
#                                     Origin Display Name  \
# ...

# %%
conversion = lambda x: x.weekday()
bart_origins['Day of Week'] = bart_origins['Date'].apply(conversion)
bart_origins.head()
# Out:
# C:\Users\QYK\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Date  Origin Movement ID             Origin Display Name  \
# 1 2019-04-28                3603  Embarcadero, San Francisco, CA
# 2 2019-05-18                3603  Embarcadero, San Francisco, CA
# 6 2019-04-23                3603  Embarcadero, San Francisco, CA
# 7 2019-05-13                3603  Embarcadero, San Francisco, CA
# 9 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# ...

# %% [markdown]
# ## Check for null values

# %%
barts_to_all.isnull().sum()
# Out:
# Origin Movement ID                           0
# Origin Display Name                          0
# Destination Movement ID                      0
# Destination Display Name                     0
# Date Range                                   0
# Mean Travel Time (Seconds)                   0
# Range - Lower Bound Travel Time (Seconds)    0
# Range - Upper Bound Travel Time (Seconds)    0
# dtype: int64

# %%
bart_origins.isnull().sum()
# Out:
# Date                                                          0
# Origin Movement ID                                            0
# Origin Display Name                                           0
# Destination Movement ID                                       0
# Destination Display Name                                      0
# Daily Mean Travel Time (Seconds)                             44
# Daily Range - Lower Bound Travel Time (Seconds)              44
# Daily Range - Upper Bound Travel Time (Seconds)              44
# AM Mean Travel Time (Seconds)                               842
# AM Range - Lower Bound Travel Time (Seconds)                842
# AM Range - Upper Bound Travel Time (Seconds)                842
# PM Mean Travel Time (Seconds)                               448
# PM Range - Lower Bound Travel Time (Seconds)                448
# PM Range - Upper Bound Travel Time (Seconds)                448
# Midday Mean Travel Time (Seconds)                           353
# ...

# %%
hotspots_to_all.isnull().sum()
# Out:
# Origin Movement ID                           0
# Origin Display Name                          0
# Destination Movement ID                      0
# Destination Display Name                     0
# Date Range                                   0
# Mean Travel Time (Seconds)                   0
# Range - Lower Bound Travel Time (Seconds)    0
# Range - Upper Bound Travel Time (Seconds)    0
# dtype: int64

# %%
hours_q1.isnull().sum()
# Out:
# sourceid                                    0
# dstid                                       0
# hod                                         0
# mean_travel_time                            0
# standard_deviation_travel_time              0
# geometric_mean_travel_time                  0
# geometric_standard_deviation_travel_time    0
# dtype: int64

# %%
hours_q2.isnull().sum()
# Out:
# sourceid                                    0
# dstid                                       0
# hod                                         0
# mean_travel_time                            0
# standard_deviation_travel_time              0
# geometric_mean_travel_time                  0
# geometric_standard_deviation_travel_time    0
# dtype: int64

# %% [markdown]
# ### Try to impute null values in the Daily Mean Travel Time (Seconds) column of barts_hotspots

# %%
bart_origins = bart_origins.reset_index(drop=True)
bart_origins
# Out:
#            Date  Origin Movement ID  \
# 0    2019-04-28                3603
# 1    2019-05-18                3603
# 2    2019-04-23                3603
# 3    2019-05-13                3603
# 4    2019-04-14                3603
# ...         ...                 ...
# 1624 2019-02-13                3760
# 1625 2019-03-18                3760
# 1626 2019-01-09                3760
# 1627 2019-02-04                3760
# 1628 2019-03-04                3760
#
#                                     Origin Display Name  \
# 0                        Embarcadero, San Francisco, CA
# 1                        Embarcadero, San Francisco, CA
# 2                        Embarcadero, San Francisco, CA
# 3                        Embarcadero, San Francisco, CA
# 4                        Embarcadero, San Francisco, CA
# ...                                                 ...
# 1624  Powell BART Station, Market St and Powell St, ...
# 1625  Powell BART Station, Market St and Powell St, ...
# ...

# %%
#from different barts to fisherman
bart_origins_fisherman = bart_origins.loc[bart_origins['Destination Movement ID'] == 3394]
seaborn.lineplot(x = 'Date', y = 'Daily Mean Travel Time (Seconds)', hue = 'Origin Movement ID', 
                 palette = seaborn.color_palette("Set1", 3), data = bart_origins_fisherman, ci = None)

# %%
#from different barts to palace
bart_origins_oracle = bart_origins.loc[bart_origins['Destination Movement ID'] == 3792]
seaborn.lineplot(x = 'Date', y = 'Daily Mean Travel Time (Seconds)', hue = 'Origin Movement ID', 
                 palette = seaborn.color_palette("Set1", 3), data = bart_origins_oracle, ci = None)

# %%
#from different barts to oracle
bart_origins_palace = bart_origins.loc[bart_origins['Destination Movement ID'] == 3396]
seaborn.lineplot(x = 'Date', y = 'Daily Mean Travel Time (Seconds)', hue = 'Origin Movement ID', 
                 palette = seaborn.color_palette("Set1", 3), data = bart_origins_palace, ci = None)

# %% [markdown]
# From the graphs we see that there are obvious up and downs with respect to time, so we can impute the null values in Daily Mean Travel Time by incrementing or decrementing nearby values.

# %%
#graph the travel from Powell to The palace
df = bart_origins
pow_pal = df.loc[(df['Origin Movement ID'] == 3760) & 
                 (df['Destination Movement ID'] == 3396)][['Date', 'Daily Mean Travel Time (Seconds)']]
pow_pal = pow_pal.sort_values('Date').reset_index(drop=True)

x = pow_pal.loc[range(181),'Date']
y = pow_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_pow_pal = pow_pal.set_index('Date').interpolate('time').reset_index()

x = new_pow_pal.loc[range(180),'Date']
#x = range(181)
y = new_pow_pal.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_pow_pal.loc[new_pow_pal['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3760 and
        row['Destination Movement ID'] == 3396 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Montgomery to The palace
df = bart_origins
mont_pal = df.loc[(df['Origin Movement ID'] == 3692) & 
                 (df['Destination Movement ID'] == 3396)][['Date', 'Daily Mean Travel Time (Seconds)']]
mont_pal = mont_pal.sort_values('Date').reset_index(drop=True)

x = mont_pal.loc[range(181),'Date']
y = mont_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_mont_pal = mont_pal.set_index('Date').interpolate('time').reset_index()

x = new_mont_pal.loc[range(180),'Date']
#x = range(181)
y = new_mont_pal.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_mont_pal.loc[new_mont_pal['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3692 and
        row['Destination Movement ID'] == 3396 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Embarcadero to The palace
df = bart_origins
emba_pal = df.loc[(df['Origin Movement ID'] == 3603) & 
                 (df['Destination Movement ID'] == 3396)][['Date', 'Daily Mean Travel Time (Seconds)']]
emba_pal = emba_pal.sort_values('Date').reset_index(drop=True)

x = emba_pal.loc[range(181),'Date']
y = emba_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_emba_pal = emba_pal.set_index('Date').interpolate('time').reset_index()

x = new_emba_pal.loc[range(180),'Date']
#x = range(181)
y = new_emba_pal.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_emba_pal.loc[new_emba_pal['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3603 and
        row['Destination Movement ID'] == 3396 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Powell to Fisherman
df = bart_origins
pow_fish = df.loc[(df['Origin Movement ID'] == 3760) & 
                 (df['Destination Movement ID'] == 3394)][['Date', 'Daily Mean Travel Time (Seconds)']]
pow_fish = pow_fish.sort_values('Date').reset_index(drop=True)

x = pow_fish.loc[range(181),'Date']
y = pow_fish.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_pow_fish = pow_fish.set_index('Date').interpolate('time').reset_index()

x = new_pow_fish.loc[range(180),'Date']
#x = range(181)
y = new_pow_fish.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_pow_fish.loc[new_pow_fish['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3760 and
        row['Destination Movement ID'] == 3394 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Montgomery to Fisherman
df = bart_origins
mont_fish = df.loc[(df['Origin Movement ID'] == 3692) & 
                 (df['Destination Movement ID'] == 3394)][['Date', 'Daily Mean Travel Time (Seconds)']]
mont_fish = mont_fish.sort_values('Date').reset_index(drop=True)

x = mont_fish.loc[range(181),'Date']
y = mont_fish.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_mont_fish = mont_fish.set_index('Date').interpolate('time').reset_index()

x = new_mont_fish.loc[range(180),'Date']
#x = range(181)
y = new_mont_fish.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_mont_fish.loc[new_mont_fish['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3692 and
        row['Destination Movement ID'] == 3394 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Embarcadero to Fisherman
df = bart_origins
emba_fish = df.loc[(df['Origin Movement ID'] == 3603) & 
                 (df['Destination Movement ID'] == 3394)][['Date', 'Daily Mean Travel Time (Seconds)']]
emba_fish = emba_fish.sort_values('Date').reset_index(drop=True)

x = emba_fish.loc[range(181),'Date']
y = emba_fish.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_emba_fish = emba_fish.set_index('Date').interpolate('time').reset_index()

x = new_emba_fish.loc[range(180),'Date']
#x = range(181)
y = new_emba_fish.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_emba_fish.loc[new_emba_fish['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3603 and
        row['Destination Movement ID'] == 3394 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Powell to Oracle
df = bart_origins
pow_orac = df.loc[(df['Origin Movement ID'] == 3760) & 
                 (df['Destination Movement ID'] == 3792)][['Date', 'Daily Mean Travel Time (Seconds)']]
pow_orac = pow_orac.sort_values('Date').reset_index(drop=True)

x = pow_orac.loc[range(181),'Date']
y = pow_orac.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_pow_orac = pow_orac.set_index('Date').interpolate('time').reset_index()

x = new_pow_orac.loc[range(180),'Date']
#x = range(181)
y = new_pow_orac.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_pow_orac.loc[new_pow_orac['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3760 and
        row['Destination Movement ID'] == 3792 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Montgomery to Oracle
df = bart_origins
mont_orac = df.loc[(df['Origin Movement ID'] == 3692) & 
                 (df['Destination Movement ID'] == 3792)][['Date', 'Daily Mean Travel Time (Seconds)']]
mont_orac = mont_orac.sort_values('Date').reset_index(drop=True)

x = mont_orac.loc[range(181),'Date']
y = mont_orac.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_mont_orac = mont_orac.set_index('Date').interpolate('time').reset_index()

x = new_mont_orac.loc[range(180),'Date']
#x = range(181)
y = new_mont_orac.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_mont_orac.loc[new_mont_orac['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3692 and
        row['Destination Movement ID'] == 3792 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
#graph the travel from Embarcadero to Oracle
df = bart_origins
emba_orac = df.loc[(df['Origin Movement ID'] == 3603) & 
                 (df['Destination Movement ID'] == 3792)][['Date', 'Daily Mean Travel Time (Seconds)']]
emba_orac = emba_orac.sort_values('Date').reset_index(drop=True)

x = emba_orac.loc[range(181),'Date']
y = emba_orac.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#Imputation
new_emba_orac = emba_orac.set_index('Date').interpolate('time').reset_index()

x = new_emba_orac.loc[range(180),'Date']
#x = range(181)
y = new_emba_orac.loc[range(180),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
#impute to the original dataframe
impute = lambda x: new_emba_orac.loc[new_emba_orac['Date'] == x['Date']]['Daily Mean Travel Time (Seconds)'].iloc[0]
for i in range(len(bart_origins)):
    row = bart_origins.iloc[i]
    if (row['Origin Movement ID'] == 3603 and
        row['Destination Movement ID'] == 3792 and
        np.isnan(row['Daily Mean Travel Time (Seconds)'])):
        imputed = impute(row)
        bart_origins = bart_origins.set_value(i, 'Daily Mean Travel Time (Seconds)', imputed)
bart_origins.head()
# Out:
#         Date  Origin Movement ID             Origin Display Name  \
# 0 2019-04-28                3603  Embarcadero, San Francisco, CA
# 1 2019-05-18                3603  Embarcadero, San Francisco, CA
# 2 2019-04-23                3603  Embarcadero, San Francisco, CA
# 3 2019-05-13                3603  Embarcadero, San Francisco, CA
# 4 2019-04-14                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 0                     3394               Fisherman's Wharf, San Francisco, CA
# 1                     3394               Fisherman's Wharf, San Francisco, CA
# 2                     3394               Fisherman's Wharf, San Francisco, CA
# 3                     3394               Fisherman's Wharf, San Francisco, CA
# 4                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 0                             639.0
# ...

# %%
bart_origins.isnull().sum()
# Out:
# Date                                                          0
# Origin Movement ID                                            0
# Origin Display Name                                           0
# Destination Movement ID                                       0
# Destination Display Name                                      0
# Daily Mean Travel Time (Seconds)                              0
# Daily Range - Lower Bound Travel Time (Seconds)              44
# Daily Range - Upper Bound Travel Time (Seconds)              44
# AM Mean Travel Time (Seconds)                               842
# AM Range - Lower Bound Travel Time (Seconds)                842
# AM Range - Upper Bound Travel Time (Seconds)                842
# PM Mean Travel Time (Seconds)                               448
# PM Range - Lower Bound Travel Time (Seconds)                448
# PM Range - Upper Bound Travel Time (Seconds)                448
# Midday Mean Travel Time (Seconds)                           353
# ...

# %% [markdown]
# All nulls in the Daily Mean Travel Time (Seconds) column have been imputed. Let's check whether other columns with null values have the same pattern. If yes, imputing by incrementing/decrementing could be the best approach to impute nulls.

# %% [markdown]
# # Part 1

# %% [markdown]
# ## Make recommendation for bart station according to hotspot and day of week

# %%
bart_origins_dow = bart_origins[['Origin Display Name',
                                'Destination Movement ID',
                                'Daily Mean Travel Time (Seconds)',
                                'Day of Week']]
bart_origins_dow
# Out:
#                                     Origin Display Name  \
# 0                        Embarcadero, San Francisco, CA
# 1                        Embarcadero, San Francisco, CA
# 2                        Embarcadero, San Francisco, CA
# 3                        Embarcadero, San Francisco, CA
# 4                        Embarcadero, San Francisco, CA
# ...                                                 ...
# 1624  Powell BART Station, Market St and Powell St, ...
# 1625  Powell BART Station, Market St and Powell St, ...
# 1626  Powell BART Station, Market St and Powell St, ...
# 1627  Powell BART Station, Market St and Powell St, ...
# 1628  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  Daily Mean Travel Time (Seconds)  Day of Week
# 0                        3394                             639.0            6
# 1                        3394                             730.0            5
# ...

# %%
#groupby hotspots, day of week and barts
grouped = pd.DataFrame(bart_origins.groupby(['Destination Movement ID', 
                                             'Day of Week',
                                             'Origin Display Name'])['Daily Mean Travel Time (Seconds)'].mean())
grouped
# Out:
#                                                                                         Daily Mean Travel Time (Seconds)
# Destination Movement ID Day of Week Origin Display Name
# 3394                    0           2nd Street and Stevenson Street (Montgomery BAR...                        755.760000
#                                     Embarcadero, San Francisco, CA                                            655.200000
#                                     Powell BART Station, Market St and Powell St, S...                        861.160000
#                         1           2nd Street and Stevenson Street (Montgomery BAR...                        778.615385
#                                     Embarcadero, San Francisco, CA                                            651.423077
# ...                                                                                                                  ...
# ...

# %%
grouped = grouped.reset_index()
grouped
# Out:
#     Destination Movement ID  Day of Week  \
# 0                      3394            0
# 1                      3394            0
# 2                      3394            0
# 3                      3394            1
# 4                      3394            1
# ..                      ...          ...
# 58                     3792            5
# 59                     3792            5
# 60                     3792            6
# 61                     3792            6
# 62                     3792            6
#
#                                   Origin Display Name  \
# 0   2nd Street and Stevenson Street (Montgomery BA...
# 1                      Embarcadero, San Francisco, CA
# 2   Powell BART Station, Market St and Powell St, ...
# 3   2nd Street and Stevenson Street (Montgomery BA...
# 4                      Embarcadero, San Francisco, CA
# ..                                                ...
# 58                     Embarcadero, San Francisco, CA
# ...

# %% [markdown]
# ## analyze the three hotspots separately

# %%
#split the grouped df according to the destination
fisherman = grouped.loc[0:20].iloc[:, 1:]
palace = grouped.loc[21:41].iloc[:, 1:]
oracle = grouped.loc[42:].iloc[:, 1:]

# %%
#fisherman
seaborn.factorplot(x='Day of Week', y='Daily Mean Travel Time (Seconds)', hue='Origin Display Name', data = fisherman, kind='bar')

# %% [markdown]
# It seems that 3603: 'Embarcadero, San Francisco, CA' is the best bart to get off for any day of week.

# %%
id_name_dict
# Out:
# {3396: 'The Palace Of Fine Arts, 3601 Lyon St, San Francisco, CA',
#  3603: 'Embarcadero, San Francisco, CA',
#  3792: 'Oracle Park, 24 Willie Mays Plaza, San Francisco, CA',
#  3394: "Fisherman's Wharf, San Francisco, CA",
#  3692: '2nd Street and Stevenson Street (Montgomery BART, San Francisco, CA',
#  3760: 'Powell BART Station, Market St and Powell St, San Francisco, CA'}

# %%
#palace
seaborn.factorplot(x='Day of Week', y='Daily Mean Travel Time (Seconds)', hue='Origin Display Name', data = palace, kind='bar')

# %% [markdown]
# It seems that 3603: 'Embarcadero, San Francisco, CA' is the best bart to get off for any day of week.

# %%
#oracle
seaborn.factorplot(x='Day of Week', y='Daily Mean Travel Time (Seconds)', hue='Origin Display Name', data = oracle, kind='bar')

# %% [markdown]
# It seems that 3692: '2nd Street and Stevenson Street (Montgomery BART), San Francisco, CA' is the best bart to get off for any day of week.

# %% [markdown]
# ## Making recommendations for going from hotspots to barts

# %% [markdown]
# # Building Models

# %% [markdown]
# We will build a model that takes in the date attribute and outputs the travelling time.

# %%
import warnings
import itertools
from pylab import rcParams
import statsmodels.api as sm

# %%
y = bart_origins[['Date', 'Daily Mean Travel Time (Seconds)']].set_index('Date')
y
# Out:
#             Daily Mean Travel Time (Seconds)
# Date
# 2019-04-28                             639.0
# 2019-05-18                             730.0
# 2019-04-23                             682.0
# 2019-05-13                             634.0
# 2019-04-14                             996.0
# ...                                      ...
# 2019-02-13                             956.0
# 2019-03-18                             916.0
# 2019-01-09                             795.0
# 2019-02-04                            1162.5
# 2019-03-04                             869.0
#
# [1629 rows x 1 columns]

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 0, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# C:\Users\QYK\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0369      0.025     -1.467      0.142      -0.086       0.012
# ar.S.L12      -0.0086      0.026     -0.331      0.741      -0.060       0.042
# ma.S.L12      -0.9416      0.011    -87.893      0.000      -0.963      -0.921
# sigma2      9.645e+04   4040.645     23.869      0.000    8.85e+04    1.04e+05
# ...

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()
