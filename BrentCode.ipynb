# %%
import pandas as pd
import numpy as np
import impyute
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv('barts_hotspots.csv')
ids_of_interest = df['Origin Movement ID'].unique()
dest_of_interest = df['Origin Display Name'].unique()
id_names = dict(zip(ids_of_interest, dest_of_interest))
id_names

# %%
def to_weekday(x):
    return x.weekday()
weekdays = df['Date'].apply(pd.to_datetime).apply(to_weekday)
df['Weekday'] = weekdays
df['Datetime'] = df['Date'].apply(pd.to_datetime)
df

# %%
df.columns
# Out:
# Index(['Date', 'Origin Movement ID', 'Origin Display Name',
#        'Destination Movement ID', 'Destination Display Name',
#        'Daily Mean Travel Time (Seconds)',
#        'Daily Range - Lower Bound Travel Time (Seconds)',
#        'Daily Range - Upper Bound Travel Time (Seconds)',
#        'AM Mean Travel Time (Seconds)',
#        'AM Range - Lower Bound Travel Time (Seconds)',
#        'AM Range - Upper Bound Travel Time (Seconds)',
#        'PM Mean Travel Time (Seconds)',
#        'PM Range - Lower Bound Travel Time (Seconds)',
#        'PM Range - Upper Bound Travel Time (Seconds)',
#        'Midday Mean Travel Time (Seconds)',
#        'Midday Range - Lower Bound Travel Time (Seconds)',
#        'Midday Range - Upper Bound Travel Time (Seconds)',
#        'Evening Mean Travel Time (Seconds)',
#        'Evening Range - Lower Bound Travel Time (Seconds)',
#        'Evening Range - Upper Bound Travel Time (Seconds)',
#        'Early Morning Mean Travel Time (Seconds)',
# ...

# %%
pow_pal = df.loc[(df['Origin Movement ID']== 3760) & (df['Destination Movement ID']==3396)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
pow_pal = pow_pal.sort_values('Datetime').reset_index(drop=True)

embarc_pal = df.loc[(df['Origin Movement ID']== 3603) & (df['Destination Movement ID']==3396)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
embarc_pal = embarc_pal.sort_values('Datetime').reset_index(drop=True)

mont_pal = df.loc[(df['Origin Movement ID']== 3692) & (df['Destination Movement ID']==3396)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
mont_pal = mont_pal.sort_values('Datetime').reset_index(drop=True)

pow_ora = df.loc[(df['Origin Movement ID']== 3760) & (df['Destination Movement ID']==3792)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
pow_ora = mont_pal.sort_values('Datetime').reset_index(drop=True)

embarc_ora = df.loc[(df['Origin Movement ID']== 3603) & (df['Destination Movement ID']==3792)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
embarc_ora = mont_pal.sort_values('Datetime').reset_index(drop=True)

mont_ora = df.loc[(df['Origin Movement ID']== 3692) & (df['Destination Movement ID']==3792)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
mont_ora = mont_pal.sort_values('Datetime').reset_index(drop=True)

pow_fish = df.loc[(df['Origin Movement ID']== 3760) & (df['Destination Movement ID']==3394)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
pow_fish = mont_pal.sort_values('Datetime').reset_index(drop=True)

embarc_fish = df.loc[(df['Origin Movement ID']== 3603) & (df['Destination Movement ID']==3394)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
embarc_fish = mont_pal.sort_values('Datetime').reset_index(drop=True)

mont_fish = df.loc[(df['Origin Movement ID']== 3692) & (df['Destination Movement ID']==3394)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
mont_fish = mont_pal.sort_values('Datetime').reset_index(drop=True)

pal_pow = df.loc[(df['Origin Movement ID']== 3396) & (df['Destination Movement ID']==3760)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
pal_pow = mont_pal.sort_values('Datetime').reset_index(drop=True)

pal_embarc = df.loc[(df['Origin Movement ID']== 3396) & (df['Destination Movement ID']==3603)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
pal_embarc = mont_pal.sort_values('Datetime').reset_index(drop=True)

pal_mont = df.loc[(df['Origin Movement ID']== 3396) & (df['Destination Movement ID']==3692)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
pal_mont = mont_pal.sort_values('Datetime').reset_index(drop=True)

ora_pow = df.loc[(df['Origin Movement ID']== 3792) & (df['Destination Movement ID']==3760)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
ora_pow = mont_pal.sort_values('Datetime').reset_index(drop=True)

ora_embarc = df.loc[(df['Origin Movement ID']== 3792) & (df['Destination Movement ID']==3603)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
ora_embarc = mont_pal.sort_values('Datetime').reset_index(drop=True)

ora_mont = df.loc[(df['Origin Movement ID']== 3792) & (df['Destination Movement ID']==3692)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
ora_mont = mont_pal.sort_values('Datetime').reset_index(drop=True)

fish_pow = df.loc[(df['Origin Movement ID']== 3394) & (df['Destination Movement ID']==3760)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
fish_pow = mont_pal.sort_values('Datetime').reset_index(drop=True)

fish_embarc = df.loc[(df['Origin Movement ID']== 3394) & (df['Destination Movement ID']==3603)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
fish_embarc = mont_pal.sort_values('Datetime').reset_index(drop=True)

fish_embarc = df.loc[(df['Origin Movement ID']== 3394) & (df['Destination Movement ID']==3692)][['Datetime', 'Daily Mean Travel Time (Seconds)']]
fish_embarc = mont_pal.sort_values('Datetime').reset_index(drop=True)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=False)
x = new_pow_pal1.loc[range(90),'Datetime']
#x = range(181)
y = new_pow_pal1.loc[range(90),'Daily Mean Travel Time (Seconds)']
ax1.plot(x,y)
ax1.gcf().autofmt_xdate()

# %%
x = pow_pal.loc[range(181),'Datetime']
y = pow_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
x = embarc_pal.loc[range(181),'Datetime']
y = embarc_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
x = mont_pal.loc[range(181),'Datetime']
y = mont_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
new_pow_pal = pow_pal.set_index('Datetime').interpolate('time').reset_index()
#new_pow_pal1 = pow_pal.interpolate()
new_embarc_pal = embarc_pal.set_index('Datetime').interpolate('time').reset_index()
new_mont_pal = mont_pal.set_index('Datetime').interpolate('time').reset_index()
#new_pow_embarc[['index', 'Daily Mean Travel Time (Seconds)']].values
#type(np.array(pow_embarc['Daily Mean Travel Time (Seconds)', ' Datetime']))
#new_pow_embarc['Imputed'] = impyute.imputation.ts.locf(new_pow_embarc[['index', 'Daily Mean Travel Time (Seconds)']].values)[1]

# %%
x = new_pow_pal1.loc[range(90),'Datetime']
#x = range(181)
y = new_pow_pal1.loc[range(90),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
x = new_pow_pal.loc[range(91,181),'Datetime']
#x = range(181)
y = new_pow_pal.loc[range(91,181),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
x = new_embarc_pal.loc[range(181),'Datetime']
y = new_embarc_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
x = new_mont_pal.loc[range(181),'Datetime']
y = new_mont_pal.loc[range(181),'Daily Mean Travel Time (Seconds)']
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
nulls = df[np.isnan(df['Daily Mean Travel Time (Seconds)'])]
for i in range(7):
    print(nulls[nulls['Weekday']==i].shape[0])
# Out:
# 9
# 10
# 4
# 2
# 4
# 10
# 19

# %%
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
def to_weekday(x):
    return x.weekday()
weekdays = df['Date'].apply(pd.to_datetime).apply(to_weekday)
df['Weekday'] = weekdays
df
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 1     04/28/2019                3603
# 2     05/18/2019                3603
# 3     04/18/2019                3792
# 4     04/08/2019                3792
# 5     06/30/2019                3792
# 6     04/23/2019                3603
# 7     05/13/2019                3603
# 8     05/15/2019                3394
# 9     04/14/2019                3603
# 10    06/01/2019                3394
# 11    04/18/2019                3603
# 12    06/11/2019                3792
# 13    05/29/2019                3394
# 14    04/21/2019                3603
# 15    06/06/2019                3396
# 16    04/18/2019                3396
# 17    05/16/2019                3603
# 18    06/11/2019                3396
# 19    05/07/2019                3394
# 20    05/01/2019                3792
# 21    04/27/2019                3603
# 22    05/11/2019                3603
# 23    04/25/2019                3603
# ...

# %%
embarc_start = df.loc[df['Origin Movement ID']==360]
mont_start = df.loc[df['Origin Movement ID']==3692]
powell_start = df.loc[df['Origin Movement ID']==3760]

# %%
hoursq1 = pd.read_csv('hours_q2.csv')
hoursq1[(hoursq1['sourceid']==3396)&(hoursq1['dstid']==3760)]
# Out:
# Empty DataFrame
# Columns: [sourceid, dstid, hod, mean_travel_time, standard_deviation_travel_time, geometric_mean_travel_time, geometric_standard_deviation_travel_time]
# Index: []

# %%
df.tail()
# Out:
#             Date  Origin Movement ID  \
# 3253  01/06/2019                3396
# 3254  01/24/2019                3396
# 3255  01/09/2019                3760
# 3256  02/04/2019                3760
# 3257  03/04/2019                3760
#
#                                     Origin Display Name  \
# 3253  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3254  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3255  Powell BART Station, Market St and Powell St, ...
# 3256  Powell BART Station, Market St and Powell St, ...
# 3257  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 3253                     3760
# 3254                     3760
# 3255                     3792
# 3256                     3396
# 3257                     3394
#
#                                Destination Display Name  \
# 3253  Powell BART Station, Market St and Powell St, ...
# 3254  Powell BART Station, Market St and Powell St, ...
# ...

# %%
df.loc[df['Daily Mean Travel Time (Seconds)'].isna()]
# Out:
#             Date  Origin Movement ID  \
# 63    05/26/2019                3396
# 113   04/14/2019                3396
# 354   05/27/2019                3396
# 355   06/30/2019                3603
# 371   06/16/2019                3396
# 464   04/07/2019                3396
# 980   06/30/2019                3396
# 1043  06/30/2019                3692
# 1106  05/29/2019                3760
# 1114  04/27/2019                3760
# 1161  05/27/2019                3760
# 1166  05/05/2019                3792
# 1188  06/18/2019                3760
# 1202  05/12/2019                3760
# 1244  05/14/2019                3760
# 1248  04/26/2019                3760
# 1264  06/30/2019                3396
# 1286  05/07/2019                3760
# 1296  04/23/2019                3760
# 1503  06/29/2019                3760
# 1507  04/29/2019                3760
# 1511  05/28/2019                3396
# 1519  05/28/2019                3760
# 1569  04/10/2019                3760
# ...

# %%
def to_weekday(x):
    return x.weekday()
df['Date'].apply(pd.to_datetime).apply(to_weekday)
# Out:
# 0       6
# 1       6
# 2       5
# 3       3
# 4       0
# 5       6
# 6       1
# 7       0
# 8       2
# 9       6
# 10      5
# 11      3
# 12      1
# 13      2
# 14      6
# 15      3
# 16      3
# 17      3
# 18      1
# 19      1
# 20      2
# 21      5
# 22      5
# 23      3
# 24      6
# 25      4
# 26      2
# 27      3
# 28      0
# 29      3
#        ..
# 3228    1
# 3229    5
# 3230    0
# 3231    5
# 3232    5
# 3233    0
# 3234    4
# 3235    4
# 3236    1
# 3237    6
# 3238    4
# 3239    3
# 3240    2
# 3241    4
# 3242    1
# 3243    4
# 3244    0
# 3245    4
# 3246    1
# 3247    2
# 3248    3
# 3249    0
# 3250    0
# 3251    2
# 3252    2
# 3253    6
# 3254    3
# 3255    2
# 3256    0
# 3257    0
# Name: Date, Length: 3258, dtype: int64

# %%
df.head()
# Out:
#          Date  Origin Movement ID  \
# 0  06/09/2019                3396
# 1  04/28/2019                3603
# 2  05/18/2019                3603
# 3  04/18/2019                3792
# 4  04/08/2019                3792
#
#                                  Origin Display Name  Destination Movement ID  \
# 0  The Palace Of Fine Arts, 3601 Lyon St, San Fra...                     3603
# 1                     Embarcadero, San Francisco, CA                     3394
# 2                     Embarcadero, San Francisco, CA                     3394
# 3  Oracle Park, 24 Willie Mays Plaza, San Francis...                     3603
# 4  Oracle Park, 24 Willie Mays Plaza, San Francis...                     3603
#
#                Destination Display Name  Daily Mean Travel Time (Seconds)  \
# 0        Embarcadero, San Francisco, CA                            1588.0
# 1  Fisherman's Wharf, San Francisco, CA                             639.0
# ...
